# %%
# Import library yang dibutuhkan
import pandas as pd
from sklearn.datasets import load_iris

# Load dataset iris
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target

# Melihat dimensi dataset
print("Dimensi dataset:", df.shape)

# Melihat 5 baris pertama dataset
print("\nLima baris pertama dataset:\n", df.head())

# Melihat informasi dataset
print("\nInformasi dataset:\n", df.info())

# Melihat deskripsi statistik dataset
print("\nDeskripsi statistik dataset:\n", df.describe())

# Melihat distribusi kelas target
print("\nDistribusi kelas target:\n", df['target'].value_counts())

# Melihat korelasi antar variabel
print("\nKorelasi antar variabel:\n", df.corr())

# Analisis lebih lanjut dapat dilakukan, seperti:
# - Visualisasi data menggunakan histogram, scatter plot, box plot, dll.
# - Mencari missing value dan outlier
# - Menganalisis distribusi data untuk setiap variabel
# - dll.
# Out:
# Dimensi dataset: (150, 5)
#
# Lima baris pertama dataset:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.datasets import load_iris

# Load dataset iris
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target

# Histogram untuk setiap variabel
df.hist(figsize=(12, 8))
plt.show()

# Scatter plot untuk melihat hubungan antar variabel
sns.pairplot(df, hue='target')
plt.show()

# Box plot untuk melihat distribusi data untuk setiap variabel
df.boxplot(figsize=(12, 8))
plt.show()

# Violin plot untuk melihat distribusi data untuk setiap variabel dan target
for col in iris.feature_names:
    sns.violinplot(x='target', y=col, data=df)
    plt.show()

# Heatmap untuk melihat korelasi antar variabel
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
# Import library yang dibutuhkan
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_iris

# Load dataset iris
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target
# Melihat jumlah nilai kosong (missing value) pada setiap kolom
print("\nJumlah nilai kosong pada setiap kolom:\n", df.isnull().sum())

# Melihat jumlah nilai duplikat pada dataset
print("\nJumlah baris duplikat:\n", df.duplicated().sum())

# Mencari outlier pada setiap variabel numerik menggunakan box plot
for col in iris.feature_names:
  plt.figure()
  sns.boxplot(x=df[col])
  plt.title(f"Box plot untuk {col}")
  plt.show()

# Mencari nilai-nilai yang mencurigakan atau tidak wajar pada setiap kolom
# Contoh: untuk kolom 'sepal length (cm)', nilai yang kurang dari 0 atau lebih dari 10 mungkin mencurigakan
# Anda dapat menyesuaikan batas-batas ini sesuai dengan pengetahuan domain Anda
for col in iris.feature_names:
  print(f"\nNilai-nilai mencurigakan pada kolom {col}:")
  print(df[(df[col] < 0) | (df[col] > 10)])  # Contoh batas nilai mencurigakan

# Melihat apakah ada nilai yang inkonsisten pada kolom target
# Contoh: jika kolom target hanya boleh berisi nilai 0, 1, dan 2, maka kita dapat memeriksa apakah ada nilai lain
print("\nNilai unik pada kolom target:", df['target'].unique())

# Periksa apakah ada ambiguitas pada data, misal pada kolom teks
# Jika ada kolom teks, Anda perlu memeriksa apakah ada nilai yang ambigu atau tidak konsisten
# Contoh: jika kolom 'nama' berisi nilai 'Andi', 'Andi S.', 'Andi Setiawan', maka dapat dianggap ambigu
# Anda dapat menggunakan teknik string matching atau fuzzy matching untuk mendeteksi ambiguitas

# Analisis lebih lanjut dapat dilakukan dengan memperhatikan konteks data dan tujuan analisis
# Misalnya, Anda dapat melakukan validasi terhadap nilai yang tidak wajar atau outlier
# dengan membandingkannya dengan nilai rata-rata, median, atau standar deviasi.
# Anda juga dapat melakukan analisis lebih lanjut terhadap nilai duplikat untuk
# memastikan bahwa duplikasi tersebut memang valid atau merupakan kesalahan input data.
# Out:
# Jumlah nilai kosong pada setiap kolom:
#  sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64
#
# Jumlah baris duplikat:
#  1
# Nilai-nilai mencurigakan pada kolom sepal length (cm):
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm), target]
# Index: []
#
# Nilai-nilai mencurigakan pada kolom sepal width (cm):
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm), target]
# Index: []
#
# Nilai-nilai mencurigakan pada kolom petal length (cm):
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm), target]
# Index: []
#
# Nilai-nilai mencurigakan pada kolom petal width (cm):
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm), target]
# Index: []
#
# Nilai unik pada kolom target: [0 1 2]

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# Load dataset iris
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target

# Kriteria pemilihan data:
# - Membagi data menjadi data training dan data testing dengan rasio 80:20
# - Menggunakan metode stratified sampling untuk memastikan distribusi kelas target
#   pada data training dan testing sama

# Teknik pemilihan data:
# - Menggunakan fungsi train_test_split dari scikit-learn

# Membagi data menjadi data training dan testing
X = df.drop('target', axis=1)
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Menampilkan ukuran data training dan testing
print("Ukuran data training:", X_train.shape)
print("Ukuran data testing:", X_test.shape)

# Menampilkan distribusi kelas target pada data training dan testing
print("\nDistribusi kelas target pada data training:\n", y_train.value_counts())
print("\nDistribusi kelas target pada data testing:\n", y_test.value_counts())
# Out:
# Ukuran data training: (120, 4)
# Ukuran data testing: (30, 4)
#
# Distribusi kelas target pada data training:
#  target
# 0    40
# 2    40
# 1    40
# Name: count, dtype: int64
#
# Distribusi kelas target pada data testing:
#  target
# 0    10
# 2    10
# 1    10
# Name: count, dtype: int64
# Ukuran data training: (120, 4)
# Ukuran data testing: (30, 4)
#
# Distribusi kelas target pada data training:
#  target
# 0    40
# 2    40
# 1    40
# Name: count, dtype: int64
#
# Distribusi kelas target pada data testing:
#  target
# 0    10
# 2    10
# 1    10
# Name: count, dtype: int64

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# Load dataset iris
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target


X = df.drop('target', axis=1)
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)


# Records (rows) dari data training
records_train = X_train.shape[0]
print("\nRecords (rows) data training:", records_train)

# Records (rows) dari data testing
records_test = X_test.shape[0]
print("\nRecords (rows) data testing:", records_test)
# Out:
# Records (rows) data training: 120
#
# Records (rows) data testing: 30

# %%
# prompt: Berdasarkan langkah sebelumnya (seleksi kolom dan baris), lakukan penggabungan dataset (misalnya, kita gabungkan dataset dengan dirinya sendiri untuk menunjukkan proses penggabungan) serta pemeriksaan kualitas integrasi data dan formatting agar sesuai untuk tujuan pemodelan data science.

import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# Load dataset iris
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df['target'] = iris.target
# Menggabungkan dataset dengan dirinya sendiri
merged_df = pd.concat([df, df], axis=0)

# Mengecek ukuran dataset yang digabungkan
print("Ukuran dataset yang digabungkan:", merged_df.shape)

# Mengecek apakah ada duplikat setelah penggabungan
print("\nJumlah baris duplikat setelah penggabungan:\n", merged_df.duplicated().sum())

# Mengecek tipe data setiap kolom
print("\nTipe data setiap kolom:\n", merged_df.dtypes)

# Mengecek missing value pada dataset yang digabungkan
print("\nJumlah nilai kosong pada setiap kolom:\n", merged_df.isnull().sum())


# Pemeriksaan kualitas integrasi data:
# - Periksa konsistensi data antar kolom
# - Periksa apakah ada nilai yang tidak wajar atau outlier
# - Periksa apakah format data sudah sesuai dengan yang dibutuhkan oleh model

# Contoh:
# - Jika ada kolom tanggal, pastikan formatnya sama
# - Jika ada kolom numerik, pastikan tidak ada nilai yang tidak wajar
# - Jika ada kolom kategorikal, pastikan tidak ada nilai yang ambigu

# Formatting data agar sesuai dengan tujuan pemodelan:
# - Pastikan semua kolom memiliki tipe data yang sesuai
# - Pastikan nama kolom tidak mengandung spasi atau karakter khusus
# - Pastikan data sudah dinormalisasi atau distandarisasi jika dibutuhkan

# Contoh:
# - Konversi kolom tanggal ke format datetime
# - Mengganti spasi pada nama kolom dengan underscore
# - Melakukan normalisasi data menggunakan MinMaxScaler


# Contoh formatting data:
merged_df.columns = [col.replace(' ', '_') for col in merged_df.columns]
# Misalnya, jika ingin menggunakan MinMaxScaler untuk normalisasi data
# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# merged_df[['sepal_length_(cm)', 'sepal_width_(cm)', 'petal_length_(cm)', 'petal_width_(cm)']] = scaler.fit_transform(merged_df[['sepal_length_(cm)', 'sepal_width_(cm)', 'petal_length_(cm)', 'petal_width_(cm)']])

# Menampilkan dataset yang sudah digabungkan dan diformat
print("\nDataset yang sudah digabungkan dan diformat:\n", merged_df)
